# %% [markdown]
# ## Installing Required Libraries

# %%
# !pip install datasets
# Out:
# Requirement already satisfied: datasets in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (5.0.0)
# Requirement already satisfied: filelock in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from datasets) (3.15.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=21.0.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from datasets) (24.0.0)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from datasets) (0.4.1)
# Requirement already satisfied: pandas in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from datasets) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from datasets) (2.32.3)
# Requirement already satisfied: httpx<1.0.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from datasets) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from datasets) (4.66.4)
# Requirement already satisfied: xxhash in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from datasets) (3.7.0)
# Requirement already satisfied: multiprocess<0.70.20 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from datasets) (0.70.19)
# Requirement already satisfied: fsspec<=2026.4.0,>=2023.1.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from datasets) (1.19.0)
# Requirement already satisfied: packaging in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (3.13.3)
# Requirement already satisfied: anyio in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from httpx<1.0.0->datasets) (4.12.1)
# Requirement already satisfied: certifi in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from httpx<1.0.0->datasets) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from httpx<1.0.0->datasets) (1.0.6)
# Requirement already satisfied: idna in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from httpx<1.0.0->datasets) (3.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.14.0)
# Requirement already satisfied: click>=8.4.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (8.4.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.5.1)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (0.25.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.15.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub<2.0,>=0.25.0->datasets) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub<2.0,>=0.25.0->datasets) (14.0.0)
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub<2.0,>=0.25.0->datasets) (0.0.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: colorama in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from click>=8.4.0->huggingface-hub<2.0,>=0.25.0->datasets) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.32.2->datasets) (1.26.20)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub<2.0,>=0.25.0->datasets) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\pooja\appdata\roaming\python\python312\site-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub<2.0,>=0.25.0->datasets) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub<2.0,>=0.25.0->datasets) (0.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)

# %%
# !pip install pandas numpy scikit-learn nltk seaborn matplotlib torch transformers datasets
# Out:
# Requirement already satisfied: pandas in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (1.26.4)
# Requirement already satisfied: scikit-learn in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (1.5.2)
# Requirement already satisfied: nltk in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (3.9.1)
# Requirement already satisfied: seaborn in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (0.13.2)
# Requirement already satisfied: matplotlib in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (3.9.2)
# Requirement already satisfied: torch in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (2.9.1)
# Requirement already satisfied: transformers in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (5.12.1)
# Requirement already satisfied: datasets in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (5.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: click in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from nltk) (8.4.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from nltk) (2026.5.9)
# Requirement already satisfied: tqdm in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from nltk) (4.66.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: filelock in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from torch) (70.0.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from transformers) (1.19.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.25.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.4.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: anyio in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.12.1)
# Requirement already satisfied: certifi in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.6)
# Requirement already satisfied: idna in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.14.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from typer->transformers) (14.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: pyarrow>=21.0.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from datasets) (24.0.0)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from datasets) (0.4.1)
# Requirement already satisfied: requests>=2.32.2 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from datasets) (2.32.3)
# Requirement already satisfied: xxhash in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from datasets) (3.7.0)
# Requirement already satisfied: multiprocess<0.70.20 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from datasets) (0.70.19)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (3.13.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: colorama in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.32.2->datasets) (1.26.20)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from rich>=13.8.0->typer->transformers) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\pooja\appdata\roaming\python\python312\site-packages (from rich>=13.8.0->typer->transformers) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch) (2.1.5)
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Loading The Dataset

# %%
import pandas as pd

train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")
val_df = pd.read_csv("validation.csv")

# %%
from datasets import load_dataset

dataset = load_dataset(
    "csv",
    data_files={
        "train": "train.csv",
        "validation": "validation.csv",
        "test": "test.csv"
    }
)

print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 16000
#     })
#     validation: Dataset({
#         features: ['text', 'label'],
#         num_rows: 2000
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 2000
#     })
# })

# %%
dataset['train']
dataset['validation']
dataset['test']
# Out:
# Dataset({
#     features: ['text', 'label'],
#     num_rows: 2000
# })

# %%
train_df = dataset['train'].to_pandas()
val_df   = dataset['validation'].to_pandas()
test_df  = dataset['test'].to_pandas()

# %%
train_df.head()
# Out:
#                                                 text  label
# 0                            i didnt feel humiliated      0
# 1  i can go from feeling so hopeless to so damned...      0
# 2   im grabbing a minute to post i feel greedy wrong      3
# 3  i am ever feeling nostalgic about the fireplac...      2
# 4                               i am feeling grouchy      3

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16000 entries, 0 to 15999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    16000 non-null  object
#  1   label   16000 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 250.1+ KB

# %% [markdown]
# ## Data Cleaning

# %%
train_df.isnull().sum()
# Out:
# text     0
# label    0
# dtype: int64

# %%
train_df.duplicated().sum()
# Out:
# 1

# %%
train_df.drop_duplicates(inplace=True)

# %%
train_df.duplicated().sum()
# Out:
# 0

# %%
train_df.describe()
# Out:
#               label
# count  15999.000000
# mean       1.565973
# std        1.501471
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        3.000000
# max        5.000000

# %%
print(dataset["train"][:5])
# Out:
# {'text': ['i didnt feel humiliated', 'i can go from feeling so hopeless to so damned hopeful just from being around someone who cares and is awake', 'im grabbing a minute to post i feel greedy wrong', 'i am ever feeling nostalgic about the fireplace i will know that it is still on the property', 'i am feeling grouchy'], 'label': [0, 0, 3, 2, 3]}

# %%
dataset["train"].features
# Out:
# {'text': Value('string'), 'label': Value('int64')}

# %%
len(dataset['train'])
# Out:
# 16000

# %%
sum([1 for x in dataset['train'] if x['text'] is None])
# Out:
# 0

# %%
from datasets import ClassLabel

class_names = ["sadness", "joy", "love", "anger", "fear", "surprise"]

dataset = dataset.cast_column("label", ClassLabel(names=class_names))

# %%
dataset["train"].features["label"].names
# Out:
# ['sadness', 'joy', 'love', 'anger', 'fear', 'surprise']

# %%
from collections import Counter

labels = dataset["train"]["label"]
label_counts = Counter(labels)

for label_id, count in label_counts.items():
    emotion = dataset["train"].features["label"].names[label_id]
    print(f"{emotion}: {count}")
# Out:
# sadness: 4666
# anger: 2159
# love: 1304
# surprise: 572
# fear: 1937
# joy: 5362

# %% [markdown]
# ## Exploratory Data Analysis(EDA)

# %%
from collections import Counter
import matplotlib.pyplot as plt

labels = dataset["train"]["label"]

# Count labels
label_counts = Counter(labels)

# Map label IDs to emotion names
label_names = dataset["train"].features["label"].names

emotions = [label_names[i] for i in label_counts.keys()]
counts = [label_counts[i] for i in label_counts.keys()]

# Plot
plt.bar(emotions, counts)
plt.title("Emotion Label Distribution")
plt.xlabel("Emotion")
plt.ylabel("Count")
plt.show()

# %%
train_df['text_length'] = train_df['text'].apply(len)

import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.hist(train_df['text_length'], bins=50)
plt.title("Text Length Distribution")
plt.xlabel("Length of Text")
plt.ylabel("Frequency")
plt.show()

# %%
train_df['word_count'] = train_df['text'].apply(lambda x: len(x.split()))

plt.figure(figsize=(8,5))
plt.hist(train_df['word_count'], bins=50)
plt.title("Word Count Distribution")
plt.xlabel("Number of Words")
plt.ylabel("Frequency")
plt.show()

# %%
train_df['label'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Class Distribution")
plt.ylabel('')
plt.show()

# %%
from collections import Counter

all_words = " ".join(train_df['text']).split()
common_words = Counter(all_words).most_common(10)

words, counts = zip(*common_words)

plt.figure(figsize=(8,5))
plt.bar(words, counts)
plt.xticks(rotation=45)
plt.title("Top 10 Most Common Words")
plt.show()

# %% [markdown]
# ## 1. TF-IDF + Logistic Regression Model

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# %%
# Train
X_train = dataset["train"]["text"]
y_train = dataset["train"]["label"]

X_test = dataset["test"]["text"]
y_test = dataset["test"]["label"]

# %%
tfidf = TfidfVectorizer(
    max_features=10000,
    ngram_range=(1, 2),
    stop_words="english"
)

X_train_tfidf = tfidf.fit_transform(X_train)

X_test_tfidf = tfidf.transform(X_test)

# %%
model = LogisticRegression(max_iter=1000)

model.fit(X_train_tfidf, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = model.predict(X_test_tfidf)

# %%
test_acc_lr = accuracy_score(y_test, y_pred)

print("Logistic Regression Test Accuracy:", test_acc_lr)
# Out:
# Logistic Regression Test Accuracy: 0.8865

# %%
label_names = ["sadness", "joy", "love", "anger", "fear", "surprise"]

print(classification_report(
    y_test,
    y_pred,
    target_names=label_names
))
# Out:
#               precision    recall  f1-score   support
#
#      sadness       0.91      0.95      0.93       581
#          joy       0.86      0.96      0.91       695
#         love       0.82      0.64      0.72       159
#        anger       0.92      0.83      0.87       275
#         fear       0.90      0.85      0.87       224
#     surprise       0.94      0.52      0.67        66
#
#     accuracy                           0.89      2000
#    macro avg       0.89      0.79      0.83      2000
# weighted avg       0.89      0.89      0.88      2000

# %% [markdown]
# ## 2. LSTM Model

# %%
X_train = dataset["train"]["text"]
y_train = dataset["train"]["label"]

X_val = dataset["validation"]["text"]
y_val = dataset["validation"]["label"]

X_test = dataset["test"]["text"]
y_test = dataset["test"]["label"]

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

vocab_size = 15000
max_len = 200

tokenizer = Tokenizer(num_words=vocab_size, oov_token="<OOV>")
tokenizer.fit_on_texts(X_train)

X_train_seq = tokenizer.texts_to_sequences(X_train)
X_val_seq   = tokenizer.texts_to_sequences(X_val)
X_test_seq  = tokenizer.texts_to_sequences(X_test)

X_train_pad = pad_sequences(X_train_seq, maxlen=max_len, padding="post")
X_val_pad   = pad_sequences(X_val_seq, maxlen=max_len, padding="post")
X_test_pad  = pad_sequences(X_test_seq, maxlen=max_len, padding="post")

# %%
import numpy as np

y_train = np.array(y_train)
y_val   = np.array(y_val)
y_test  = np.array(y_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional

model = Sequential([
    Embedding(vocab_size, 128),

    Bidirectional(LSTM(128, return_sequences=True)),
    Dropout(0.5),

    Bidirectional(LSTM(64)),
    Dropout(0.5),

    Dense(64, activation='relu'),
    Dropout(0.5),

    Dense(6, activation='softmax')
])

# %%
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
history = model.fit(
    X_train_pad,
    y_train,
    epochs=5,
    batch_size=64,
    validation_data=(X_val_pad, y_val)
)
# Out:
# Epoch 1/5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 419s 2s/step - accuracy: 0.4293 - loss: 1.3914 - val_accuracy: 0.6845 - val_loss: 0.8708
# Epoch 2/5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 519s 2s/step - accuracy: 0.8124 - loss: 0.5595 - val_accuracy: 0.8490 - val_loss: 0.4359
# Epoch 3/5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 508s 2s/step - accuracy: 0.9089 - loss: 0.2911 - val_accuracy: 0.9005 - val_loss: 0.3030
# Epoch 4/5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 485s 2s/step - accuracy: 0.9394 - loss: 0.1995 - val_accuracy: 0.9060 - val_loss: 0.3529
# Epoch 5/5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 488s 2s/step - accuracy: 0.9588 - loss: 0.1492 - val_accuracy: 0.9105 - val_loss: 0.3563

# %%
test_loss, test_acc_lstm = model.evaluate(X_test_pad, y_test)
print("LSTM Test Accuracy:", test_acc_lstm)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 14s 229ms/step - accuracy: 0.9005 - loss: 0.3529
# LSTM Test Accuracy: 0.9004999995231628

# %%
label_names = ["sadness", "joy", "love", "anger", "fear", "surprise"]
num_labels = 6

# %% [markdown]
# ## 3. DISTILBERT Model

# %%
from transformers import DistilBertTokenizerFast

tokenizer = DistilBertTokenizerFast.from_pretrained("distilbert-base-uncased")

def tokenize(batch):
    return tokenizer(
        batch["text"],
        padding="max_length",
        truncation=True,
        max_length=128
    )

tokenized_dataset = dataset.map(tokenize, batched=True)

tokenized_dataset = tokenized_dataset.remove_columns(["text"])
tokenized_dataset = tokenized_dataset.rename_column("label", "labels")
tokenized_dataset.set_format("torch")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Map:   0%|          | 0/16000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2000 [00:00<?, ? examples/s]

# %%
from transformers import DistilBertForSequenceClassification

model = DistilBertForSequenceClassification.from_pretrained(
    "distilbert-base-uncased",
    num_labels=num_labels
)
# Out:
# Loading weights:   0%|          | 0/100 [00:00<?, ?it/s]
# [transformers] DistilBertForSequenceClassification LOAD REPORT from: distilbert-base-uncased
# Key                     | Status     |
# ------------------------+------------+-
# vocab_projector.bias    | UNEXPECTED |
# vocab_layer_norm.weight | UNEXPECTED |
# vocab_transform.bias    | UNEXPECTED |
# vocab_transform.weight  | UNEXPECTED |
# vocab_layer_norm.bias   | UNEXPECTED |
# pre_classifier.weight   | MISSING    |
# pre_classifier.bias     | MISSING    |
# classifier.bias         | MISSING    |
# classifier.weight       | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.

# %%
import numpy as np
from sklearn.metrics import accuracy_score

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    preds = np.argmax(logits, axis=1)
    return {"accuracy": accuracy_score(labels, preds)}

# %%
pip install accelerate -U
# Out:
# Requirement already satisfied: accelerate in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (1.14.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from accelerate) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from accelerate) (25.0)
# Requirement already satisfied: psutil in c:\users\pooja\appdata\roaming\python\python312\site-packages (from accelerate) (6.1.0)
# Requirement already satisfied: pyyaml in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=2.0.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from accelerate) (2.9.1)
# Requirement already satisfied: huggingface_hub>=0.21.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from accelerate) (1.19.0)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from accelerate) (0.4.4)
# Requirement already satisfied: click>=8.4.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (2024.6.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (0.28.1)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (4.66.4)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (0.25.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (4.15.0)
# Requirement already satisfied: anyio in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate) (4.12.1)
# Requirement already satisfied: certifi in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate) (1.0.6)
# Requirement already satisfied: idna in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate) (3.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate) (0.14.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from typer<0.26.0,>=0.20.0->huggingface_hub>=0.21.0->accelerate) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from typer<0.26.0,>=0.20.0->huggingface_hub>=0.21.0->accelerate) (14.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from typer<0.26.0,>=0.20.0->huggingface_hub>=0.21.0->accelerate) (0.0.4)
# Requirement already satisfied: colorama in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from click>=8.4.0->huggingface_hub>=0.21.0->accelerate) (0.4.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface_hub>=0.21.0->accelerate) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\pooja\appdata\roaming\python\python312\site-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface_hub>=0.21.0->accelerate) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface_hub>=0.21.0->accelerate) (0.1.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from torch>=2.0.0->accelerate) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from torch>=2.0.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from torch>=2.0.0->accelerate) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from torch>=2.0.0->accelerate) (70.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch>=2.0.0->accelerate) (2.1.5)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install -U accelerate
# Out:
# Requirement already satisfied: accelerate in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (1.14.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from accelerate) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from accelerate) (25.0)
# Requirement already satisfied: psutil in c:\users\pooja\appdata\roaming\python\python312\site-packages (from accelerate) (6.1.0)
# Requirement already satisfied: pyyaml in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=2.0.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from accelerate) (2.9.1)
# Requirement already satisfied: huggingface_hub>=0.21.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from accelerate) (1.19.0)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from accelerate) (0.4.4)
# Requirement already satisfied: click>=8.4.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (2024.6.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (0.28.1)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (4.66.4)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (0.25.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (4.15.0)
# Requirement already satisfied: anyio in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate) (4.12.1)
# Requirement already satisfied: certifi in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate) (1.0.6)
# Requirement already satisfied: idna in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate) (3.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate) (0.14.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from typer<0.26.0,>=0.20.0->huggingface_hub>=0.21.0->accelerate) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from typer<0.26.0,>=0.20.0->huggingface_hub>=0.21.0->accelerate) (14.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from typer<0.26.0,>=0.20.0->huggingface_hub>=0.21.0->accelerate) (0.0.4)
# Requirement already satisfied: colorama in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from click>=8.4.0->huggingface_hub>=0.21.0->accelerate) (0.4.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface_hub>=0.21.0->accelerate) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\pooja\appdata\roaming\python\python312\site-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface_hub>=0.21.0->accelerate) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface_hub>=0.21.0->accelerate) (0.1.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from torch>=2.0.0->accelerate) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from torch>=2.0.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from torch>=2.0.0->accelerate) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from torch>=2.0.0->accelerate) (70.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch>=2.0.0->accelerate) (2.1.5)
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install -U "transformers[torch]"
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: transformers[torch] in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (5.12.1)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from transformers[torch]) (1.19.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from transformers[torch]) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from transformers[torch]) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from transformers[torch]) (6.0.1)
# Requirement already satisfied: regex>=2025.10.22 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from transformers[torch]) (2026.5.9)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from transformers[torch]) (0.22.2)
# Requirement already satisfied: typer in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from transformers[torch]) (0.25.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from transformers[torch]) (0.4.4)
# Requirement already satisfied: tqdm>=4.60 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from transformers[torch]) (4.66.4)
# Requirement already satisfied: torch>=2.4 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from transformers[torch]) (2.9.1)
# Requirement already satisfied: accelerate>=1.1.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from transformers[torch]) (1.14.0)
# Requirement already satisfied: click>=8.4.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (2024.6.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (4.15.0)
# Requirement already satisfied: anyio in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (4.12.1)
# Requirement already satisfied: certifi in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (1.0.6)
# Requirement already satisfied: idna in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (3.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (0.14.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from typer->transformers[torch]) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from typer->transformers[torch]) (14.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from typer->transformers[torch]) (0.0.4)
# Requirement already satisfied: psutil in c:\users\pooja\appdata\roaming\python\python312\site-packages (from accelerate>=1.1.0->transformers[torch]) (6.1.0)
# Requirement already satisfied: colorama in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from click>=8.4.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (0.4.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from rich>=13.8.0->typer->transformers[torch]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\pooja\appdata\roaming\python\python312\site-packages (from rich>=13.8.0->typer->transformers[torch]) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers[torch]) (0.1.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from torch>=2.4->transformers[torch]) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from torch>=2.4->transformers[torch]) (3.3)
# Requirement already satisfied: jinja2 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from torch>=2.4->transformers[torch]) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from torch>=2.4->transformers[torch]) (70.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from sympy>=1.13.3->torch>=2.4->transformers[torch]) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pooja\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch>=2.4->transformers[torch]) (2.1.5)

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
    output_dir="./results",
    eval_strategy="epoch",
    save_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=3,
    weight_decay=0.01,
    logging_dir="./logs",
    load_best_model_at_end=True,
)
# Out:
# [transformers] `logging_dir` is deprecated and will be removed in v5.2. Please set `TENSORBOARD_LOGGING_DIR` instead.

# %%
from transformers import Trainer

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset["train"],
    eval_dataset=tokenized_dataset["validation"],
    compute_metrics=compute_metrics
)

# %% [markdown]
# ## DISTILBERT Model Training

# %%
trainer.train()
# Out:
# C:\Users\Pooja\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='153' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 153/3000 29:10 < 9:10:08, 0.09 it/s, Epoch 0.15/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>

# %%
results = trainer.evaluate(tokenized_dataset["test"])

test_acc_bert = results["eval_accuracy"]

print("DistilBERT Test Accuracy:", test_acc_bert)

# %% [markdown]
# ## Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

preds = trainer.predict(tokenized_dataset["test"])

y_pred = preds.predictions.argmax(axis=1)
y_true = preds.label_ids

cm = confusion_matrix(y_true, y_pred)

disp = ConfusionMatrixDisplay(cm, display_labels=label_names)
disp.plot(xticks_rotation=45)
plt.show()

# %%
trainer.save_model("./emotion_model")
tokenizer.save_pretrained("./emotion_model")

# %% [markdown]
# ## Models Comparison

# %%
import pandas as pd

performance_df = pd.DataFrame({
    "Model": ["TF-IDF + Logistic Regression", "LSTM", "DistilBERT"],
    "Accuracy": [test_acc_lr, test_acc_lstm, test_acc_bert],
    "Type": ["Traditional ML", "Deep Learning", "Transformer"],
    "Training Time": ["Fast", "Medium", "Slow"],
    "Performance Level": ["Very Good", "Very Good", "Best"]
})

performance_df

# %% [markdown]
# ## Deployment

# %%
from transformers import pipeline
from IPython.display import display, HTML

classifier = pipeline(
    "text-classification",
    model="./emotion_model",
    tokenizer="./emotion_model"
)

label_map = {
    0: "sadness",
    1: "joy",
    2: "love",
    3: "anger",
    4: "fear",
    5: "surprise"
}

def predict_emotion_ui(text):
    result = classifier(text)[0]

    label_index = int(result["label"].split("_")[1])
    emotion = label_map[label_index].upper()
    confidence = result["score"]

    html_output = f"""
    <div style="
        font-family: Arial;
        width: 600px;
        margin: 20px auto;
        padding: 25px;
        border-radius: 30px;
        background: linear-gradient(135deg, #f5f7fa, #c3cfe2);
        box-shadow: 0 8px 20px rgba(0,0,0,0.2);
    ">
        <h2 style="text-align:center;">Emotion Detection</h2>

        <div style="
            background: white;
            padding: 15px;
            border-radius: 20px;
            margin-top: 10px;
        ">
            {text}
        </div>

        <div style="
            margin-top: 20px;
            padding: 20px;
            border-radius: 25px;
            background: linear-gradient(135deg, #d4edda, #a8e6cf);
            color: #155724;
            text-align: center;
            font-size: 18px;
        ">
            <b>Emotion:</b> {emotion} <br><br>
            <b>Confidence:</b> {confidence:.2f}
        </div>
    </div>
    """

    display(HTML(html_output))

# %%
import ipywidgets as widgets
from IPython.display import display


text_input = widgets.Textarea(
    placeholder="Enter your text...",
    layout=widgets.Layout(width='600px', height='100px')
)

# Button
button = widgets.Button(description="Detect Emotion", button_style='success')

# Output
output = widgets.Output()

def on_click(b):
    with output:
        output.clear_output()
        text = text_input.value

        if text.strip() == "":
            print("Please enter some text!")
        else:
            predict_emotion_ui(text)

button.on_click(on_click)

display(text_input, button, output)
